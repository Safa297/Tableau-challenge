# %%
import pandas as pd

# %%
# Specify the file paths of the CSV files
file1 = 'JC-202307-citibike-tripdata.csv'
file2 = 'JC-202312-citibike-tripdata.csv'

# Read the CSV files into DataFrames
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)

# %%
# Assuming df1 and df2 are your DataFrames
combined_df = pd.concat([df1, df2], axis=0)

#Print DF
combined_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      7A68381621C25F78   classic_bike  2023-07-17 17:16:34
# 1      0F814CA67B2FA120   classic_bike  2023-07-26 19:40:15
# 2      775A38967EBF5FB4  electric_bike  2023-07-01 12:12:22
# 3      D93B742DCE1C1447   classic_bike  2023-07-20 19:10:18
# 4      AA7A6863B4B92169  electric_bike  2023-07-07 19:33:59
# ...                 ...            ...                  ...
# 58675  7E862701EE7A6A03   classic_bike  2023-12-20 17:55:41
# 58676  DFAF91AB91BE25DB   classic_bike  2023-12-13 14:36:43
# 58677  AEE7B49E6EDFAE6F   classic_bike  2023-12-18 16:40:00
# 58678  A38E98956AD72EFB   classic_bike  2023-12-02 13:42:51
# 58679  F16E0B969D877368   classic_bike  2023-12-19 16:30:13
#
#                   ended_at     start_station_name start_station_id  \
# 0      2023-07-17 17:20:52            Astor Place            JC077
# 1      2023-07-26 19:44:37        Adams St & 2 St            HB407
# 2      2023-07-01 12:27:45        McGinley Square            JC055
# 3      2023-07-20 19:17:22  Baldwin at Montgomery            JC020
# 4      2023-07-07 19:58:17  Baldwin at Montgomery            JC020
# ...                    ...                    ...              ...
# 58675  2023-12-20 18:00:10       Heights Elevator            JC059
# 58676  2023-12-13 14:42:31       Heights Elevator            JC059
# 58677  2023-12-18 16:45:45        6 St & Grand St            HB302
# 58678  2023-12-02 13:50:42        6 St & Grand St            HB302
# 58679  2023-12-19 16:36:54        6 St & Grand St            HB302
#
#                              end_station_name end_station_id  start_lat  \
# 0                     Communipaw & Berry Lane          JC084  40.719225
# 1               9 St HBLR - Jackson St & 8 St          HB305  40.739727
# 2                              Riverview Park          JC057  40.725340
# 3                                Brunswick St          JC023  40.723455
# 4      Mama Johnson Field - 4 St & Jackson St          HB404  40.723659
# ...                                       ...            ...        ...
# 58675                   Bloomfield St & 15 St          HB203  40.748720
# 58676                   Bloomfield St & 15 St          HB203  40.748767
# 58677                   Bloomfield St & 15 St          HB203  40.744291
# 58678                   Bloomfield St & 15 St          HB203  40.744398
# 58679                       Clinton St & 7 St          HB303  40.744398
#
#        start_lng    end_lat    end_lng member_casual
# 0     -74.071281  40.714358 -74.066611        member
# 1     -74.036866  40.747907 -74.038412        member
# 2     -74.067622  40.744319 -74.043991        member
# 3     -74.064359  40.724176 -74.050656        member
# 4     -74.064194  40.743140 -74.040041        casual
# ...          ...        ...        ...           ...
# 58675 -74.040487  40.754530 -74.026580        casual
# 58676 -74.040470  40.754530 -74.026580        member
# 58677 -74.034404  40.754530 -74.026580        member
# 58678 -74.034501  40.754530 -74.026580        member
# 58679 -74.034501  40.745420 -74.033320        member
#
# [165288 rows x 13 columns]

# %%
# Save the combined DataFrame to a CSV file
combined_df.to_csv('combined_citibike_data.csv', index=False)
